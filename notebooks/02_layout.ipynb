# %%
# %load_ext autoreload
# %autoreload 2
import matplotlib.pyplot as plt
import numpy as np
from src import corpus,keymap,optimization

from tqdm import tqdm

# %%
char_freqs,bigram_matrix,chars=corpus.get_matrix_from_json("ressources/fre_en.json")

# %%
ergo_chords=keymap.generate_ergonomic_chords()

# %%
random_layout=keymap.generate_random_layout(len(ergo_chords))
keymap.plot_layout(random_layout,ergo_chords,chars)
plt.show()

# %%
print(keymap.check_uniqueness_of_chords(keymap.mutate(random_layout,1)))
# Out:
# True

# %%
c=keymap.crossover(random_layout,random_layout)
print(keymap.check_uniqueness_of_chords(c))
# Out:
# True
